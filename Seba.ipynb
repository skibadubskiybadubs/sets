# %% [markdown]
# A set is an **unordered** collection of distinct objects called elements or members of the set. A set can be defined by simply listing its members inside curly braces. For example, the set {2,4,17,23} is the same as the set {17,4,23,2}. To denote membership we use the symbol **∈**. For example, **2 ∈ {2,4,17,23}**.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     X = {1, 2, 3, 4} # X is the universe where the elements of M an N live (total amount of elements)
#     M = {1, 2, 3}
#     N = {1, 2} # every element of the set N is an element of the set M
#
#     N is a subset on of M (N⊆M) = When the elements of N are fully contaiend in M.
#     ⊂ - the symbol for subset (fully contaiend but not equal).
#     ⊆ - fully contained or equal.

# %% [markdown]
# ## Things to compute (of a set)
#
# # Power set (its power set)
# Power set - is a set of all the possible subsets.
#
# **P(x) = {∅, X, {1}, {1,2}, {1,3}, {1,4}, {2,3}, {3,4}, {2}, {3}, {4}, {1,2,3}, {1,3,4}, {3,2,4}}**
#
#     [X] = 3
#     If len(X) == 4 : subsets of size 1 ({1,}, {2}), size 2 ({1,2}, {1,3}), size 3 ({1,2,3},{1,3,4}).
#
#     P(x) - set of all the sets (and subsets) of X =
#     =(the subsets of X are)=
#     = empty set, X itself, all the indiviadual elements of X and all their combinations,
#     and all the possible sets of size tree
#
#     P(x) - the set of all the subsets. (of X)
#     ∅ - empty set (the easiest subset that satisfies that) (it is always a subset of every set).
#     X - the set itself (a set is contained in itself).
#     {1} - a susbet of elements 1.
#     {1,2} - a subset of 1,2...
#
#     |P(x)| = 14
#
# _____________________________________________________________________________________________
# In general:
# |A| = n :::::: |P(A)| = 2^n

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## OPERATIONS BETWEEN SETS
#
# # union ∪
# ![image.png](attachment:image.png)
#
# # intersection ∩
# ![image-2.png](attachment:image-2.png)
#
# # difference \
# ![image-3.png](attachment:image-3.png)
#
# # complement A∁ ( A′)
# The complement is basically what we are missing to be in the entire universe.
# The Complement of a Set A is the set of all the elements which are the elements of Universal set but not the elements of A. It is represented by symbol A′ or Ac.
#     **A′ = {x: x U, x A}**
#     **A′ = U-A**
#
# ![image-5.png](attachment:image-5.png)
#
#     A′ is represented by the shaded portion in the above picture.
#     This shows all the elements which are not the elements of A.
#
#     **Both A and A′ are the subsets of Universal set. **
#     **And both are the two disjoint sets as there is no common element within them. **
#
#     Example
#     U = {x: x N} that is, the set of all natural numbers
#     A = {x: x O} that is, the set of all odd natural numbers.
#     A′ = {x: x E} that is, the set of all even numbers.
#     A′ = U-A
#
#     There are two types of complement of sets:
#     - Relative Complement(difference of sets)
#     - Absolute Complement
#
#
# + Relative Complement (Difference of Sets)
#
#     The Relative Complement of set A with respect to set B is the set of all the elements present in B
#     but not in A. It is also called the difference of two sets A and B represents as “A-B”. Here is
#     the relation of complements of set A and B only not related to universal set.
#
#     the difference that is, A-B, and vice versa, yellow portion shows, B-A
# ![image-6.png](attachment:image-6.png)
#
#     **A-B is not necessarily equal to B-A.**
#     **Relationship between set differences**
#
#     Example
#     A = {2, 3, 4, 5, 6, 7}
#     B = {3, 5, 7, 9, 11, 13}
#     A-B = {2, 4, 6}
#     B-A = {9, 11, 13}
#     A′-B′ = B-A
#
#     Properties of Relative Complement​:
#     - Complement Laws
#     - Difference Laws
#
#     Complement Laws :
#     **A-A = ∅**
#         [This shows that A –A will always be an empty set]
#     **A-∅ = A**
#         [A-∅ will always be the set itself]
#     **∅-A = ∅**
#         [∅ -A will always be the empty set]
#
#     Difference Laws :
#     **A-(∪C) = (A-B) ∩ (A-C)**
#     **A-(B∩C) = (A-B) ∪ (A-C)**
#
#
# + Absolute Complement
#
#     Absolute complement is simply the complement of A that is, the set of all the elements present in U but not in A. It is the relative complement of A in U.
#
#     Complement of A:
#     A′ = U-A
#     A′ = {x: x U, x A}
# ![image-4.png](attachment:image-4.png)
#
#     Properties of Absolute Complement:
#     - Complement Laws
#     - Law of empty and Universal Set
#     - Double Complement Law
#     - De Morgan’s Law
#
#
#     Complement Laws :
#     **A∪A′=U**
#     The union of the set and its complement will always be the universal set as both are the subset of universal set and together they contain all the elements of universal set.
#     **A∩A′ = ∅**
#     The intersection of the set and its complement will always be the empty set as these are two disjoint sets and they have no common element within them.
#
#
#     Law of empty and Universal Set :
#     **U′={x: x U} =∅**
#     As universal set is the set of all the elements regarding our consideration then there is no element left without it. So the complement of a universal set is always empty set.
#     **∅′ = U**
#     The complement of the empty set is universal set.
#     **If A⊂B then B′⊂A′**
#
#
#     Double Complement Law :
#     If A is the subset of U then A′ is also the subset of U, as all the elements of A and A′ both are the elements of universal set.
#     **Let U = {a, e, i, o, u} and A = {a, e}**
#     **A′= {i, o, u}** [that is, all the elements which are not the elements of A]
#     **(A′)′ ={x: x∈U and x∉A}′**
#     **= {a, e} =A**
#     This shows that the complement of the complement of a set is the set itself.
#     **(A′ )′ = A**
#
#
#     De Morgan’s Law :
#     De Morgan's laws are a pair of transformation rules. They are named after Augustus De Morgan.
#
#     De Morgan’s Law of Union :
#     The complement of the union of two sets is the same as the intersection of their complements.
#     It can be expressed in Boolean algebra as,
#     **(A ∪ B)′ = A′ ∩ B′**
#
#     Let’s try to prove the expression:
#
#     **Left hand side**
# ![image-7.png](attachment:image-7.png)
#
#     **Right hand side**
# ![image-8.png](attachment:image-8.png)
#
#     **Intersection of complement of A and the complement of B**
# ![image-9.png](attachment:image-9.png)
#
#     As the last image of both left hand side and the right hand side is same.
#     Hence this proves that (A ∪ B)′ = A′ ∩ B′
#
#
#     De Morgan’s law of intersection :
#     The complement of the intersection of two sets is the same as the union of their complements.
#     It can be expressed in Boolean algebra as
#
#     **(A ∩ B)′ = A′ ∪ B′**
#
#     Let’s try to prove the expression:
#
#     **Left hand side**
# ![image-10.png](attachment:image-10.png)
#
#     **Right hand side**
# ![image-11.png](attachment:image-11.png)
#
#     **Intersection of complement of A and the complement of B**
# ![image-12.png](attachment:image-12.png)
#
#     As the last image of both left hand side and the right hand side is same.
#     Hence this proves that (A ∩ B )′ = A′ ∪ B′
#
#
# # Cartesian product X (*)
# When you take M cross N = form something like coordinates [M,N]
# ![image-13.png](attachment:image-13.png)
# ![image-14.png](attachment:image-14.png)

# %% [markdown]
# ### Topological properties
#
# ## Open set (0,1)
# Open set does not include its boundary
# (0,1) = {xЄR : 0<x<1}
# boundary of a set = a set or real numbers, such that 0 less than x and x is less than 1
#
#
# ## Closed set [0,1]
# Clsoed set includes its boundary
# [0,1] = {xЄR : 0≤x≤1}
# boundary of a set = a set or real numbers, such that 0 less or equal than x and x is less or equal than 1
#
#
# ## Compact set (0,1]
# Sets that are neither open nor closed
# (0,1] = 0<x≤1}

# %% [markdown]
# ### Relations and Mappings
# https://www.mathsisfun.com/sets/function.html
#
# ## Domain
#     The domain of a relation is the set of all first elements (inputs) of the ordered pairs
#
# ## Image
#     The image is the set of all second elements (outputs) of the ordered pairs
#
# ## Relation
#     Relationship between two sets (a relation is a set of ordered pairs)
#     M, N (I can relate their elements)
#     Relationship is a way of connecting elements between sets.
#
#     A relationship has a domain and an image.
#     To which element in M in the domain I am going to assign an image.
# ![image.png](attachment:image.png)
#
#     Not every relationship is a function.
#     Example:
#
#     Take 1 element from the domain, and relate it to 2 elements in the image.
#     This does not define a function, because we don't know who to pick (which element/image).
# ![image-2.png](attachment:image-2.png)
#
# # Functions
#     A function relates an input to an output
#
# **Two important properties that a function has:**
#
# - Injectivity
#
#     For any 2 distinct elements of the domain: their images are different
# ![image-3.png](attachment:image-3.png)
#
#     F(x) = x
#     Function F for any real number it returns itself.
# ![image-5.png](attachment:image-5.png)
#
#     This is an example of not-injected function
#     (You can find 2 points in the domains of the function, whose image is the same.
# ![image-4.png](attachment:image-4.png)
#
#     F(x) = x^2
#     (1^2) = 1
#     (-1^2) = 1
# ![image-6.png](attachment:image-6.png)
#
# - Surjectivity
#
#
#
#
#
#
# ***Inverse function***
#
#     Identify each element in a grid (for example row and number)
# ![image-7.png](attachment:image-7.png)
#
#     F(element) -> grid
#
#     What if some parts of the grid are occupied
# ![image-8.png](attachment:image-8.png)
#
#     I need to find a cell that is empty
#     So I will need to go from the grid to the elements:
#     grid -> F(elements)
#
#     So I need to inverse the function.
#     From image to the domain.
